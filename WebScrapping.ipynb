# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasjha-maker/WebScrapping/blob/main/WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests as r
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

url='https://www.ambitionbox.com/list-of-companies?campaign=homepage_companies_widget&page'

# %%
webpage=r.get(url,headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-0946cdc16f15.css" media="all" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-3946c959759a.css" media="all" rel="stylesheet"/>
# ...

# %%
soup.find('div').text
# Out:
# '\n\nSkip to content\n\n\n\n\n\n\n\nToggle navigation\n\n\n\n\n\n\n\n\n\n\n            Sign\xa0up\n          \n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n        Product\n        \n\n\n\n\n\n\n\n\n\n\n\n\nActions\n        Automate any workflow\n      \n\n\n\n\n\n\n\nPackages\n        Host and manage packages\n      \n\n\n\n\n\n\n\nSecurity\n        Find and fix vulnerabilities\n      \n\n\n\n\n\n\n\nCodespaces\n        Instant dev environments\n      \n\n\n\n\n\n\n\nCopilot\n        Write better code with AI\n      \n\n\n\n\n\n\n\nCode review\n        Manage code changes\n      \n\n\n\n\n\n\n\nIssues\n        Plan and track work\n      \n\n\n\n\n\n\n\nDiscussions\n        Collaborate outside of code\n      \n\n\n\n\nExplore\n\n\n\n      All features\n\n    \n\n\n\n      Documentation\n\n    \n\n\n\n\n\n      GitHub Skills\n\n    \n\n\n\n\n\n      Blog\n\n    \n\n\n\n\n\n\n\n\n\n        Solutions\n        \n\n\n\n\n\nFor\n\n\n\n      Enterprise\n\n    \n\n\n\n      Teams\n\n    \n\n\n\n      St
# ...

# %%
len(soup.findAll('p'))
# Out:
# 12

# %%
for i in soup.findAll('h2'):
  print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# ICICI Bank
# HDFC Bank
# Wipro
# Infosys
# Capgemini
# Tech Mahindra
# Genpact
# HCLTech
# Amazon
# Axis Bank
# Concentrix Corpo...
# IBM
# Reliance Jio
# Larsen & Toubro ...
# HDB Financial Se...
# Vodafone Idea
# Teleperformance
# Reliance Retail
# Kotak Mahindra B...
# Deloitte
# Reliance Industr...
# BYJU'S
# Bharti Airtel
# Tata Motors
# Flipkart
# WNS
# IndusInd Bank

# %%
for i in soup.find_all('p',class_ ='rating'):
  print(i.text.strip())
# Out:
# 3.9
# 4.1
# 3.9
# 4.0
# 4.0
# 3.9
# 3.9
# 3.9
# 3.7
# 4.0
# 3.8
# 4.2
# 3.9
# 4.0
# 4.2
# 4.0
# 4.1
# 4.0
# 4.2
# 3.6
# 4.1
# 3.9
# 4.1
# 4.1
# 3.4
# 4.1
# 4.1
# 4.2
# 3.7
# 3.8

# %%
for i in soup.find_all('a',class_='review-count'):
  print(i.text.strip())
# Out:
# (54.5k Reviews)
# (34.5k Reviews)
# (31.7k Reviews)
# (35.6k Reviews)
# (42k Reviews)
# (31k Reviews)
# (30.2k Reviews)
# (25.6k Reviews)
# (23k Reviews)
# (20.6k Reviews)
# (19.9k Reviews)
# (19.9k Reviews)
# (19.6k Reviews)
# (15.9k Reviews)
# (16.1k Reviews)
# (15.6k Reviews)
# (25.5k Reviews)
# (14.1k Reviews)
# (13.6k Reviews)
# (15.3k Reviews)
# (18.3k Reviews)
# (14.3k Reviews)
# (11k Reviews)
# (47.9k Reviews)
# (14.5k Reviews)
# (12.9k Reviews)
# (12.5k Reviews)
# (12.9k Reviews)
# (7.4k Reviews)
# (7k Reviews)

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
company
# Out:
# [<div class="company-content-wrapper"><div class="company-content"><div class="company-logo"><img alt="Tata Consultancy Services logo" class="lazy" data-src="https://static.ambitionbox.com/assets/v2/images/rs:fit:200:200:false:false/bG9jYWw6Ly8vbG9nb3Mvb3JpZ2luYWxzL3Rjcy5qcGc.webp" height="100" onerror="this.onerror=null;this.src='/static/icons/company-placeholder.svg';" src="https://static.ambitionbox.com/static/icons/company-placeholder.svg" width="100"/></div> <div class="company-info-wrapper"><div class="company-info"><div class="left"><a href="/overview/tcs-overview"><h2 class="company-name bold-title-l" title="TCS">
#  									TCS
#  								</h2></a> <div class="rating-wrapper"><p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  									3.9
#  								</p> <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/tcs-reviews">
#  									(54.5k Reviews)
# ...

# %%
len(company)
# Out:
# 30

# %%
name=[]
rating=[]
review=[]
ctype=[]
hq=[]
old=[]
employees=[]
for i in company:
  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_ ='rating').text.strip())
  review.append(i.find('a',class_='review-count').text.strip())
  ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())

# %%
d={'name':name,
    'rating':rating,
    'reviews':review,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':old,
    'No_of_Employee':employees,
    }

# %%
d
# Out:
# {'name': ['TCS',
#   'Accenture',
#   'Cognizant',
#   'ICICI Bank',
#   'HDFC Bank',
#   'Wipro',
#   'Infosys',
#   'Capgemini',
#   'Tech Mahindra',
#   'Genpact',
#   'HCLTech',
#   'Amazon',
#   'Axis Bank',
#   'Concentrix Corpo...',
#   'IBM',
#   'Reliance Jio',
#   'Larsen & Toubro ...',
#   'HDB Financial Se...',
#   'Vodafone Idea',
#   'Teleperformance',
#   'Reliance Retail',
#   'Kotak Mahindra B...',
#   'Deloitte',
#   'Reliance Industr...',
#   "BYJU'S",
#   'Bharti Airtel',
#   'Tata Motors',
#   'Flipkart',
#   'WNS',
#   'IndusInd Bank'],
#  'rating': ['3.9',
#   '4.1',
#   '3.9',
#   '4.0',
#   '4.0',
#   '3.9',
#   '3.9',
#   '3.9',
#   '3.7',
#   '4.0',
#   '3.8',
#   '4.2',
#   '3.9',
#   '4.0',
#   '4.2',
#   '4.0',
#   '4.1',
#   '4.0',
#   '4.2',
#   '3.6',
#   '4.1',
#   '3.9',
#   '4.1',
#   '4.1',
#   '3.4',
#   '4.1',
#   '4.1',
#   '4.2',
#   '3.7',
#   '3.8'],
#  'reviews': ['(54.5k Reviews)',
#   '(34.5k Reviews)',
#   '(31.7k Reviews)',
# ...

# %%
  df=pd.DataFrame(d)

# %%
df
# Out:
#                    name rating          reviews company_type  \
# 0                   TCS    3.9  (54.5k Reviews)       Public
# 1             Accenture    4.1  (34.5k Reviews)       Public
# 2             Cognizant    3.9  (31.7k Reviews)      Private
# 3            ICICI Bank    4.0  (35.6k Reviews)       Public
# 4             HDFC Bank    4.0    (42k Reviews)       Public
# 5                 Wipro    3.9  (31.1k Reviews)       Public
# 6               Infosys    3.9  (30.2k Reviews)       Public
# 7             Capgemini    3.9  (25.6k Reviews)       Public
# 8         Tech Mahindra    3.7    (23k Reviews)       Public
# 9               Genpact    4.0  (20.7k Reviews)       Public
# 10              HCLTech    3.8  (19.9k Reviews)       Public
# 11               Amazon    4.2  (19.9k Reviews)       Public
# 12            Axis Bank    3.9  (19.6k Reviews)       Public
# 13  Concentrix Corpo...    4.0  (15.9k Reviews)       Public
# ...

# %%
final=pd.DataFrame()
for j in range(1,11):
  headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
  webpage=r.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j),headers=headers).text
  soup=BeautifulSoup(webpage,'lxml')
  company=soup.find_all('div',class_='company-content-wrapper')
  name=[]
  rating=[]
  review=[]
  ctype=[]
  hq=[]
  old=[]
  employees=[]

# %%
import numpy as np
for i in company:

    try:
       name.append(i.find('h2').text.strip())
    except:
       name.append(np.nan)

    try:
       rating.append(i.find('p',class_='rating').text.strip())
    except:
       rating.append(np.nan)
   
    try:

      review.append(i.find('a' , class_='review-count').text.strip())
    except:
      review.append(np.nan)

    try:

      ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    except:
      ctype.append(np.nan)
    try:

      hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
    except:
      hq.append(np.nan)
    
    try:

      old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
    except:
      old.append(np.nan)
    try:
      employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    except:
      employees.append(np.nan)

# %%
d1={'name':name,
    'rating':rating,
    'reviews':review,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':old,
    'No_of_Employee':employees,
    }

# %%
df1=pd.DataFrame(employees)

# %%
d1={'name':name,
    'rating':rating,
    'reviews':review,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':old,
    }

# %%
df1
# Out:
#                              0
# 0    1 Lakh+ Employees (India)
# 1    10k-50k Employees (India)
# 2    10k-50k Employees (India)
# 3    1 Lakh+ Employees (India)
# 4    10k-50k Employees (India)
# ..                         ...
# 211  10k-50k Employees (India)
# 212                          0
# 213  10k-50k Employees (India)
# 214  10k-50k Employees (India)
# 215  10k-50k Employees (India)
#
# [216 rows x 1 columns]

# %%
f=final.append(df1,ignore_index=True)
f
# Out:
# <ipython-input-170-a0dad4e14884>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   f=final.append(df1,ignore_index=True)
#                    name rating          reviews company_type  \
# 0                   TCS    3.9  (54.5k Reviews)       Public
# 1             Accenture    4.1  (34.5k Reviews)       Public
# 2             Cognizant    3.9  (31.7k Reviews)      Private
# 3            ICICI Bank    4.0  (35.6k Reviews)       Public
# 4             HDFC Bank    4.0    (42k Reviews)       Public
# 5                 Wipro    3.9  (31.1k Reviews)       Public
# 6               Infosys    3.9  (30.2k Reviews)       Public
# 7             Capgemini    3.9  (25.6k Reviews)       Public
# 8         Tech Mahindra    3.7    (23k Reviews)       Public
# 9               Genpact    4.0  (20.7k Reviews)       Public
# 10              HCLTech    3.8  (19.9k Reviews)       Public
# ...

# %%
# saving the dataframe
df.to_csv('f.csv')
